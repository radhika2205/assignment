# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
kundanbedmutha_transportation_and_accident_prediction_dataset_path = kagglehub.dataset_download('kundanbedmutha/transportation-and-accident-prediction-dataset')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'transportation-and-accident-prediction-dataset' dataset.
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/transportation-and-accident-prediction-dataset/Synthetic_Transportation_Dataset_Expanded_v2.csv

# %%
data = pd.read_csv("/kaggle/input/transportation-and-accident-prediction-dataset/Synthetic_Transportation_Dataset_Expanded_v2.csv")

# %%
data
# Out:
#       Record_ID         Timestamp   Latitude  Longitude Road_ID  \
# 0             1  03-10-2023 09:50  32.004714  76.971961  RD-285
# 1             2  09-06-2019 08:01  10.632732  77.828652  RD-384
# 2             3  08-01-2020 01:38  12.258165  88.810189  RD-282
# 3             4  18-10-2022 05:43  34.289950  95.415253  RD-128
# 4             5  29-06-2023 23:11  31.698993  77.675486   RD-49
# ...         ...               ...        ...        ...     ...
# 5495       5496  29-06-2018 00:52  26.411744  89.346236  RD-186
# 5496       5497  23-04-2019 23:23  22.836886  76.580499  RD-442
# 5497       5498  23-12-2022 05:35  17.626293  74.393270  RD-390
# 5498       5499  18-01-2019 19:05  10.919562  72.990183  RD-277
# 5499       5500  21-12-2023 05:42  27.618074  68.852754  RD-260
#
#       Vehicle_Count  Avg_Speed(km/h) Vehicle_Type Traffic_Density Weather  \
# 0               419               90        Mixed          Medium     Fog
# 1               232              104        Mixed       Very High    Rain
# 2               339              100          Bus          Medium   Storm
# 3                74               63          Car             Low   Clear
# 4               187               73        Mixed             Low   Storm
# ...             ...              ...          ...             ...     ...
# 5495            489               73         Bike          Medium   Storm
# 5496             18               66          Bus            High   Storm
# 5497            433               81         Bike       Very High    Rain
# 5498            251               63          Car          Medium    Snow
# 5499            393               99         Bike             Low     Fog
#
#       Visibility(m)     Road_Condition Accident_Occurred Accident_Severity  \
# 0              5663  Under Maintenance               Yes             Major
# 1               896                Wet                No                 -
# 2              9369  Under Maintenance                No                 -
# 3              2510           Slippery               Yes             Fatal
# 4              3447                Wet                No                 -
# ...             ...                ...               ...               ...
# 5495           5256  Under Maintenance                No                 -
# 5496           9625                Dry                No                 -
# 5497           1746                Dry                No                 -
# 5498           7601  Under Maintenance                No                 -
# 5499           2444                Wet               Yes                 -
#
#      Alert_Generated  temperature  humidity
# 0                Yes        31.24     61.12
# 1                 No        48.52     33.07
# 2                 No        41.96     43.97
# 3                 No        37.96     59.52
# 4                 No        24.68     48.61
# ...              ...          ...       ...
# 5495              No        30.01     51.57
# 5496              No        37.38     85.60
# 5497              No        46.67     71.92
# 5498              No        37.08     45.43
# 5499              No        38.95     63.85
#
# [5500 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Record_ID          5500 non-null   int64
#  1   Timestamp          5500 non-null   object
#  2   Latitude           5500 non-null   float64
#  3   Longitude          5500 non-null   float64
#  4   Road_ID            5500 non-null   object
#  5   Vehicle_Count      5500 non-null   int64
#  6   Avg_Speed(km/h)    5500 non-null   int64
#  7   Vehicle_Type       5500 non-null   object
#  8   Traffic_Density    5500 non-null   object
#  9   Weather            5500 non-null   object
#  10  Visibility(m)      5500 non-null   int64
#  11  Road_Condition     5500 non-null   object
#  12  Accident_Occurred  5500 non-null   object
#  13  Accident_Severity  5500 non-null   object
#  14  Alert_Generated    5500 non-null   object
#  15  temperature        5500 non-null   float64
#  16  humidity           5500 non-null   float64
# dtypes: float64(4), int64(4), object(9)
# memory usage: 730.6+ KB

# %%
data = data.drop(['Record_ID','Timestamp','Road_ID','Latitude','Longitude'], axis=1)

# %% [markdown]
# # *encoding*

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
obj_cols = data.select_dtypes(include='object').columns

for col in obj_cols:
        data[col] = le.fit_transform(data[col])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Vehicle_Count      5500 non-null   int64
#  1   Avg_Speed(km/h)    5500 non-null   int64
#  2   Vehicle_Type       5500 non-null   int64
#  3   Traffic_Density    5500 non-null   int64
#  4   Weather            5500 non-null   int64
#  5   Visibility(m)      5500 non-null   int64
#  6   Road_Condition     5500 non-null   int64
#  7   Accident_Occurred  5500 non-null   int64
#  8   Accident_Severity  5500 non-null   int64
#  9   Alert_Generated    5500 non-null   int64
#  10  temperature        5500 non-null   float64
#  11  humidity           5500 non-null   float64
# dtypes: float64(2), int64(10)
# memory usage: 515.8 KB

# %%
data.isnull().sum()
# Out:
# Vehicle_Count        0
# Avg_Speed(km/h)      0
# Vehicle_Type         0
# Traffic_Density      0
# Weather              0
# Visibility(m)        0
# Road_Condition       0
# Accident_Occurred    0
# Accident_Severity    0
# Alert_Generated      0
# temperature          0
# humidity             0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5495    False
# 5496    False
# 5497    False
# 5498    False
# 5499    False
# Length: 5500, dtype: bool

# %% [markdown]
# # *model 1 asscident severity prediction*

# %%
x = data.drop(['Accident_Severity'],axis=1)
y = data['Accident_Severity']

# %%
x
# Out:
#       Vehicle_Count  Avg_Speed(km/h)  Vehicle_Type  Traffic_Density  Weather  \
# 0               419               90             3                2        1
# 1               232              104             3                3        2
# 2               339              100             1                2        4
# 3                74               63             2                1        0
# 4               187               73             3                1        4
# ...             ...              ...           ...              ...      ...
# 5495            489               73             0                2        4
# 5496             18               66             1                0        4
# 5497            433               81             0                3        2
# 5498            251               63             2                2        3
# 5499            393               99             0                1        1
#
#       Visibility(m)  Road_Condition  Accident_Occurred  Alert_Generated  \
# 0              5663               2                  1                1
# 1               896               3                  0                0
# 2              9369               2                  0                0
# 3              2510               1                  1                0
# 4              3447               3                  0                0
# ...             ...             ...                ...              ...
# 5495           5256               2                  0                0
# 5496           9625               0                  0                0
# 5497           1746               0                  0                0
# 5498           7601               2                  0                0
# 5499           2444               3                  1                0
#
#       temperature  humidity
# 0           31.24     61.12
# 1           48.52     33.07
# 2           41.96     43.97
# 3           37.96     59.52
# 4           24.68     48.61
# ...           ...       ...
# 5495        30.01     51.57
# 5496        37.38     85.60
# 5497        46.67     71.92
# 5498        37.08     45.43
# 5499        38.95     63.85
#
# [5500 rows x 11 columns]

# %%
y
# Out:
# 0       2
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5495    0
# 5496    0
# 5497    0
# 5498    0
# 5499    0
# Name: Accident_Severity, Length: 5500, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy = model.score(x_test, y_test)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.93

# %%
import pickle

# %%
pickle.dump(model,open('accuracysevirity.pkl',"wb"))

# %% [markdown]
# # *model 2 Alert generated prediction*

# %%
x2 = data.drop('Alert_Generated', axis=1)
y2 = data['Alert_Generated']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train2,x_test2,y_train2,y_test2 = train_test_split(x2,y2,test_size=0.20,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2 = RandomForestClassifier()

# %%
model2.fit(x_train2,y_train2)
# Out:
# RandomForestClassifier()

# %%
accuracy = model2.score(x_test2, y_test2)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7945454545454546

# %%
import pickle

# %%
pickle.dump(model2,open("aelertgenerated.pkl","wb"))
